# %%
# %run main.py
# Out:
# Linear Regression test_error = 0.7697
# SVM one vs. rest test_error: 0.007499999999999951
# Multiclass SVM test_error: 0.08189999999999997
# softmax test_error= 0.10050000000000003
# softmax mod3 test_error= 0.08308333333333329
# Principal Components Test Error is 0.14739999999999998
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# File /mnt/c/Users/ludov/PycharmProjects/MITxML/Project2/part1/main.py:205
#     196 plot_images(train_x[1, ])
#     199 ## Cubic Kernel ##
#     200 # TODO: Find the 10-dimensional PCA representation of the training and test set
#     201
#     202
#     203 # TODO: First fill out cubicFeatures() function in features.py as the below code requires it.
# --> 205 train_cube = cubic_features(train_pca10)
#     206 test_cube = cubic_features(test_pca10)
#
# NameError: name 'train_pca10' is not defined
